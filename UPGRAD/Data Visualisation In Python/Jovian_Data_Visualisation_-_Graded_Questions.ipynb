# %% [markdown]
# ## Data Visualisation - Graded Questions

# %% [markdown]
# `Note` - *This stub file doesn't contain the conceptual questions asked on the platform*

# %% [markdown]
# ### I) Marks Analysis
#
# In the **'Marks.csv'** file, you can find the scores obtained by 200 students in 4 subjects of a standardised test. The different columns - `Score A`, `Score B`, `Score C` and `Score D` indicate the score obtained by a particular student in the respective subjects A, B, C and D.
#
#
#
# Load the dataset to your notebook and answer the following questions

# %%
#Load the necessary Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Load the dataset
df1 = pd.read_csv(r"C:\Users\moury\UPGRAD\Data Visualisation In Python\Data Visualisation - Graded Questions\Marks.csv")

# %% [markdown]
# **Q1)** Load the dataset and plot a histogram for the `Score A` column by keeping the `number of bins to 6`. Which bin range among the following has the highest frequency?
#
# (`Note` - *The bin ranges mentioned in the options are approximate values for the bin ranges that you'll actually get when you plot the histogram*)
#
#     a)0-50
#     b)50-100
#     c)150-200
#     d)200-250

# %%
#Your code here
plt.hist(df1["Score A"], bins=6)
plt.show()

# %% [markdown]
# **Q2)** Plot a box plot for the column `Score C` and choose the correct option.
#
#     A - The 25th percentile lies between 20 and 40
#     B - The 75th percentile lies between 40 and 60
#     C - The 25th percentile lies between 0 and 20
#     D - Both B and C

# %%
#Your code here

df1["Score C"].plot.box()
# Out:
# <AxesSubplot:>

# %%
df2=df1.corr()

# %%
sns.pairplot(df2, diag_kind='hist')

# %% [markdown]
# ### II) Superstore Data
#
# In the `superstore.csv` file, you have the details of orders purchased in an American online retail store. Load the dataset, observe and analyse the different columns and answer the following questions.

# %%
#Load the dataset
df2 = pd.read_csv(r"C:\Users\moury\UPGRAD\Data Visualisation In Python\Data Visualisation - Graded Questions\superstore.csv")
import warnings
warnings.filterwarnings("ignore")
df2.head()
# Out:
#          Order ID       Ship Mode    Segment Region       Product ID  \
# 0  CA-2016-152156    Second Class   Consumer  South  FUR-BO-10001798
# 1  CA-2016-152156    Second Class   Consumer  South  FUR-CH-10000454
# 2  CA-2016-138688    Second Class  Corporate   West  OFF-LA-10000240
# 3  US-2015-108966  Standard Class   Consumer  South  FUR-TA-10000577
# 4  US-2015-108966  Standard Class   Consumer  South  OFF-ST-10000760
#
#       Sales  Quantity Discount    Profit
# 0  261.9600         2       0%   41.9136
# 1  731.9400         3       0%  219.5820
# 2   14.6200         2       0%    6.8714
# 3  957.5775         5    0.45% -383.0310
# 4   22.3680         2    0.20%    2.5164

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Order ID    9994 non-null   object
#  1   Ship Mode   9994 non-null   object
#  2   Segment     9994 non-null   object
#  3   Region      9994 non-null   object
#  4   Product ID  9994 non-null   object
#  5   Sales       9994 non-null   float64
#  6   Quantity    9994 non-null   int64
#  7   Discount    9994 non-null   object
#  8   Profit      9994 non-null   float64
# dtypes: float64(2), int64(1), object(6)
# memory usage: 702.8+ KB

# %%
#Question 1

# %%
df3 = df2[(df2.Profit < 0) & (df2.Sales < 15000)]
sns.jointplot('Sales', 'Profit', df3)
plt.show()

# %%
#Question 2

# %%
res=df2.pivot_table(index='Segment', columns='Ship Mode', values='Profit', aggfunc=np.mean)

# %%
sns.heatmap(res,cmap="Greens", annot=True)
# Out:
# <AxesSubplot:xlabel='Ship Mode', ylabel='Segment'>

# %%
#Question 3

# %%
sns.barplot(data = df2, x = 'Segment', y = 'Sales', estimator = np.mean)
# Out:
# <AxesSubplot:xlabel='Segment', ylabel='Sales'>

# %%
sns.barplot(data = df2, x = 'Segment', y = 'Sales')
# Out:
# <AxesSubplot:xlabel='Segment', ylabel='Sales'>

# %%
#Question 4

# %%
df2.head()
# Out:
#          Order ID       Ship Mode    Segment Region       Product ID  \
# 0  CA-2016-152156    Second Class   Consumer  South  FUR-BO-10001798
# 1  CA-2016-152156    Second Class   Consumer  South  FUR-CH-10000454
# 2  CA-2016-138688    Second Class  Corporate   West  OFF-LA-10000240
# 3  US-2015-108966  Standard Class   Consumer  South  FUR-TA-10000577
# 4  US-2015-108966  Standard Class   Consumer  South  OFF-ST-10000760
#
#       Sales  Quantity Discount    Profit
# 0  261.9600         2       0%   41.9136
# 1  731.9400         3       0%  219.5820
# 2   14.6200         2       0%    6.8714
# 3  957.5775         5    0.45% -383.0310
# 4   22.3680         2    0.20%    2.5164

# %% [markdown]
# **Q4)** Plot a pie-chart to find the Ship Mode through which most of the orders are being delivered.
#
#      a)Standard Class
#      b)First Class
#      c)Second Class
#      d)Same Day

# %%
plt.style.use("ggplot")
df2["Ship Mode"].value_counts().plot.pie()
# Out:
# <AxesSubplot:ylabel='Ship Mode'>

# %%
#Your code here

# %% [markdown]
# **Q5)** Plot a bar chart comparing the average `Discount` across all the `Regions` and report back the `Region` getting the highest average discount
#
# **Note** - You need to clean the `Discount` column first
#
#     a)Central
#     b)South
#     c)West
#     d)East

# %%
#Your code here
df2.groupby(df2["Region"]).disc.mean().plot.bar()
# Out:
# <AxesSubplot:xlabel='Region'>

# %%
df2.pivot_table(index='Region', values='disc', aggfunc=np.mean).plot.bar()
# Out:
# <AxesSubplot:xlabel='Region'>

# %%
sns.jointplot(df2[(df2.Sales<15000) & (df2.Profit<0)].Sales,df2[(df2.Sales<15000) & (df2.Profit<0)].Profit)
# Out:
# C:\Users\kamlesh.mittapelli\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
